# %% [markdown]
# # Data Science Course Week 2 - Lesson 2
# # Introduction to Linear Regression

# %% [markdown]
# Regression is the process of learning a mapping from a vector of input data to a quantitative output given a set of observations. For example, coordinates in a room to Wi-Fi signal strength, someone's Body Mass Index to their life expectancy or a stock's performance over the last 5 days to it's value tomorrow.
#
# There are numerous methods for addressing this problem, each with their own set of assumptions and behaviour. Some are ideal for tackling large volumes of data while others provide more informative probabilistic outputs.
#
# In this lab, we'll focus on Linear Regression; a good point of reference for many other regression techniques and still used widely around the world today due to their simplicity and favourable scaling characteristics.

# %% [markdown]
# We will be using [statsmodels](http://statsmodels.sourceforge.net/devel/examples/notebooks/generated/ols.html) for learning about linear regression. It covers the models better than in scikit when we are learning and want more insights into the model parameters. But we will mainly be using scikit learn for the rest of the course.

# %% [markdown]
# # Class Workshop

# %%
# Import the libraries required
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import numpy as np

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %% [markdown]
# Here we are using a dataset of chicago house prices. The dataset is made up of houses that sold and several variables that describe the data.

# %%
# Read in data
house_data = pd.read_csv("chicagohouseprices2.csv", index_col=0)

# %%
house_data
# Out:
#                                     Address Neighborhood           HouseType  \
# 0         2111 W Division St #5, Chicago IL  Wicker Park               Condo
# 1           1520 W Walton St #2, Chicago IL  Wicker Park               Condo
# 2              2047 W Thomas St, Chicago IL  Wicker Park   Multi-Family Home
# 3        1735 N Paulina St #314, Chicago IL  Wicker Park               Condo
# 4              1634 W Beach Ave, Chicago IL  Wicker Park   Multi-Family Home
# 5           1634 W Wabansia Ave, Chicago IL  Wicker Park  Single-Family Home
# 6            1440 N Wood St #2F, Chicago IL  Wicker Park               Condo
# 7            1137 N Wood St #F2, Chicago IL  Wicker Park               Condo
# 8               1418 N Bell Ave, Chicago IL  Wicker Park   Multi-Family Home
# 9           1308 N Bosworth Ave, Chicago IL  Wicker Park   Multi-Family Home
# 10               1025 N Wood St, Chicago IL  Wicker Park   Multi-Family Home
# 11            1732 W Pierce Ave, Chicago IL  Wicker Park   Multi-Family Home
# 12       1449 N Ashland Ave #1R, Chicago IL  Wicker Park               Condo
# 13           2116 W Potomac Ave, Chicago IL  Wicker Park   Multi-Family Home
# 14               1421 N Wood St, Chicago IL  Wicker Park  Single-Family Home
# 15        1332 N Wolcott Ave #1, Chicago IL  Wicker Park               Condo
# 16           1411 N Ashland Ave, Chicago IL  Wicker Park   Multi-Family Home
# 17           1409 N Ashland Ave, Chicago IL  Wicker Park   Multi-Family Home
# 18          1019 N Honore St #1, Chicago IL  Wicker Park               Condo
# 19              2152 W Caton St, Chicago IL  Wicker Park  Single-Family Home
# 20         1735 N Hermitage Ave, Chicago IL  Wicker Park  Single-Family Home
# 21     2300 W Wabansia Ave #124, Chicago IL  Wicker Park               Condo
# 22      1026 N Hermitage Ave #2, Chicago IL  Wicker Park                 NaN
# 23        1725 W Le Moyne St #2, Chicago IL  Wicker Park   Multi-Family Home
# 24     2089 W Wabansia Ave #307, Chicago IL  Wicker Park               Condo
# 25          1637 W Beach Ave #1, Chicago IL  Wicker Park               Condo
# 26          922 N Hermitage Ave, Chicago IL  Wicker Park   Multi-Family Home
# 27         1111 N Hermitage Ave, Chicago IL  Wicker Park               Condo
# 28       1548 N Bosworth Ave #1, Chicago IL  Wicker Park               Condo
# 29          1544 W Thomas St #2, Chicago IL  Wicker Park               Condo
# ..                                      ...          ...                 ...
# 189          1723 W Le Moyne St, Chicago IL  Wicker Park  Single-Family Home
# 190         1422 N Hoyne Ave #1, Chicago IL  Wicker Park   Multi-Family Home
# 191      1034 N Wolcott Ave #2F, Chicago IL  Wicker Park               Condo
# 192   2124 W Division St #UNIT1, Chicago IL  Wicker Park               Condo
# 193       1625 W North Ave #301, Chicago IL  Wicker Park               Condo
# 194       1732 N Winchester Ave, Chicago IL  Wicker Park  Single-Family Home
# 195      1751 W Division St #2W, Chicago IL  Wicker Park               Condo
# 196         1259 N Wood St #202, Chicago IL  Wicker Park               Condo
# 197        1532 N Paulina St #L, Chicago IL  Wicker Park               Condo
# 198          1649 N Wolcott Ave, Chicago IL  Wicker Park                 NaN
# 199            2043 W Thomas St, Chicago IL  Wicker Park  Single-Family Home
# 200           1338 N Leavitt St, Chicago IL  Wicker Park  Single-Family Home
# 201        1441 N Elk Grove Ave, Chicago IL  Wicker Park               Condo
# 202     1656 W Blackhawk St #1W, Chicago IL  Wicker Park               Condo
# 203           1928 W Crystal St, Chicago IL  Wicker Park   Multi-Family Home
# 204       2143 W Division St #4, Chicago IL  Wicker Park               Condo
# 205       1521 W Haddon Ave #2B, Chicago IL  Wicker Park               Condo
# 206       1521 W Haddon Ave #20, Chicago IL  Wicker Park               Condo
# 207            1251 N Honore St, Chicago IL  Wicker Park            Lot/Land
# 208      1901 W Division St #4S, Chicago IL  Wicker Park               Condo
# 209       2140 W Haddon Ave #1W, Chicago IL  Wicker Park               Condo
# 210             1661 N Bell Ave, Chicago IL  Wicker Park               Condo
# 211       1037 N Winchester Ave, Chicago IL  Wicker Park               Condo
# 212    2255 W Wabansia Ave #108, Chicago IL  Wicker Park               Condo
# 213         1259 N Wood St #206, Chicago IL  Wicker Park               Condo
# 214    2300 W Wabansia Ave #111, Chicago IL  Wicker Park               Condo
# 215              1746 N Wood St, Chicago IL  Wicker Park  Single-Family Home
# 216      2000 W Haddon Ave #201, Chicago IL  Wicker Park               Condo
# 217         1611 N Bell Ave #3N, Chicago IL  Wicker Park               Condo
# 218  2012 W Saint Paul Ave #202, Chicago IL  Wicker Park               Condo
#
#        Price  Bath  CrimeIndex  MinutesToLoop  MilesToLake  Age  LotSizeSqft  \
# 0     390000   NaN        2.59              9         3.91    0            0
# 1     320500   NaN        4.10              7         3.02    0            0
# 2     620000   4.0        2.09              9         3.84   94         3049
# 3     318000   NaN        2.40              9         2.90    0            0
# 4     477000   2.0        4.63              9         2.96   31         2614
# 5     695000   2.0        1.40              8         2.86   23         2614
# 6     242500   NaN        5.38              9         3.22    0            0
# 7     477500   NaN        4.18              8         3.39    0            0
# 8     466000   2.0        4.93             10         4.02  121         3049
# 9     435000   2.0        4.75              8         2.89  119         3485
# 10    303000   2.0        4.68              8         3.43  119         3049
# 11    314000   3.0        5.18              9         3.06  131         2614
# 12    146500   NaN        4.50              8         2.86    0            0
# 13    650000   3.0        3.89             10         3.86  119         3485
# 14    490500   1.0        5.38              9         3.21  124         2614
# 15    341000   NaN        5.88              9         3.40    0            0
# 16    590000   2.0        4.50              8         2.90  118         2614
# 17    590000   2.0        4.50              8         2.90  119         2614
# 18    535000   NaN        3.99              9         3.52    0            0
# 19    885000   3.0        5.58             11         3.72  121         4792
# 20    982500   3.0        4.65              9         2.98    0         2614
# 21    280000   NaN        8.08             11         3.95    0            0
# 22    380000   NaN        5.68              9         3.37    0            0
# 23    580000   3.0        5.18              9         3.08  108         2614
# 24    392500   NaN        5.58             10         3.58    0            0
# 25    267500   NaN        4.63              9         2.97    0            0
# 26    398000   2.0        4.23              8         3.42  116         3049
# 27    350000   NaN        5.38              8         3.29    0            0
# 28    359000   NaN        4.30              8         2.77    0            0
# 29    315000   NaN        5.30              7         2.98    0            0
# ..       ...   ...         ...            ...          ...  ...          ...
# 189   610000   1.0        5.18              9         3.08  115         2614
# 190   624000   3.0        3.89             10         3.76  109         3485
# 191   272500   NaN        3.29              8         3.63    0            0
# 192   290000   NaN        2.89              9         3.92    0            0
# 193   400000   NaN        2.53              7         2.89    0            0
# 194  1300000   3.0        4.65             10         3.35    0         3049
# 195   387500   NaN        5.88              8         3.31    0            0
# 196   335000   NaN        4.93              9         3.30    0            0
# 197   300000   NaN        4.93              8         3.01    0            0
# 198   660000   3.0        5.65             10         3.29  118         2614
# 199   680000   1.0        2.09              9         3.83  111         3049
# 200   322000   1.0        3.76             10         3.97  126         3049
# 201    90500   NaN        5.99              9         3.24    0            0
# 202   387000   NaN        4.63              9         3.01    0            0
# 203   580000   3.0        4.99              9         3.56  119         3049
# 204   403000   NaN        2.59              9         3.95    0            0
# 205   315000   NaN        5.50              8         2.94    0            0
# 206   315000   NaN        5.50              8         2.94    0            0
# 207  1275000   NaN        5.94             10         3.38    0            0
# 208   642000   NaN        3.99              8         3.55    0            0
# 209   501000   NaN        2.39             10         3.97    0            0
# 210   468000   NaN        6.25             11         3.88    0            0
# 211   475000   NaN        2.29              9         3.69    0            0
# 212   516000   NaN        8.08             11         3.87    0            0
# 213   339000   NaN        4.93              9         3.30    0            0
# 214   350000   NaN        8.08             11         3.95    0            0
# 215  1040000   3.0        4.65             10         3.09    8         3049
# 216   275000   NaN        2.09             10         3.74   82            0
# 217   597500   NaN        6.25             10         3.90    0            0
# 218   295000   NaN        5.58             22         3.45   41            0
#
#      HouseSizeSqft  SchoolIndex  EstimatedPrice
# 0                0         36.2        335790.0
# 1                0         91.7        376908.0
# 2             3492         36.2        629300.0
# 3                0         50.0        297330.0
# 4             1840         78.9        463644.0
# 5             1628         50.0        813150.0
# 6                0         69.4        196667.5
# 7                0         59.5        445030.0
# 8             1344         16.7        538696.0
# 9             1760         40.0        463275.0
# 10            2728         59.5        361782.0
# 11            2405         50.0        334724.0
# 12               0         78.9        139468.0
# 13            3618         16.7        680550.0
# 14             922         69.4        516987.0
# 15               0         69.4        282689.0
# 16            2544         78.9        589410.0
# 17            2352         78.9        644870.0
# 18               0         59.5        523230.0
# 19            3461         36.1        945180.0
# 20            2783         33.3       1087627.5
# 21               0         36.1        292320.0
# 22               0         22.2        449160.0
# 23            2656         50.0        596820.0
# 24               0         36.1        369342.5
# 25               0         78.9        288365.0
# 26            1344         22.2        364170.0
# 27               0         59.5        306950.0
# 28               0         50.0        357205.0
# 29               0         27.3        279405.0
# ..             ...          ...             ...
# 189            392         50.0        724680.0
# 190           3663         69.4        643344.0
# 191              0         59.5        236530.0
# 192              0         36.2        290290.0
# 193              0         50.0        450800.0
# 194           3043         36.1       1210300.0
# 195              0         59.5        332087.5
# 196              0         59.5        331985.0
# 197              0         50.0        292800.0
# 198           2777         33.3        753720.0
# 199           1214         36.2        635120.0
# 200           1260         16.7        283682.0
# 201              0         69.4         84798.5
# 202              0         78.9        329337.0
# 203           3612         59.5        657140.0
# 204              0         36.2        390104.0
# 205              0         27.3        282555.0
# 206              0         27.3        281925.0
# 207              0         59.5       1463700.0
# 208              0         59.5        641358.0
# 209              0         36.2        537573.0
# 210              0         36.1        552240.0
# 211              0         59.5        450300.0
# 212              0         36.1        444792.0
# 213              0         59.5        317304.0
# 214              0         36.1        311150.0
# 215              0         33.3        888160.0
# 216              0         59.5        241450.0
# 217              0         36.1        506680.0
# 218              0         36.1        300605.0
#
# [219 rows x 13 columns]

# %%
#house_data = house_data[np.isfinite(house_data['Bath'])]
#df = house_data.groupby(['HouseType'])
#df.plot()

# %%
house_data.shape
# Out:
# (219, 13)

# %%
# do we have any missing data?
house_data.isnull().sum()
# Out:
# Address             0
# Neighborhood        0
# HouseType           3
# Price               0
# Bath              149
# CrimeIndex          0
# MinutesToLoop       0
# MilesToLake         0
# Age                 0
# LotSizeSqft         0
# HouseSizeSqft       0
# SchoolIndex         0
# EstimatedPrice      0
# dtype: int64

# %%
# Summarise the data
house_data.describe()
#house_data.describe(include=['object'])
#house_data.describe(include='all')
# Out:
#               Price       Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# count  2.190000e+02  70.000000  219.000000     219.000000   219.000000
# mean   4.834311e+05   2.271429    4.663607       9.698630     3.420411
# std    4.001249e+05   0.883364    1.418146       2.898995     0.352522
# min    2.450000e+04   1.000000    1.090000       6.000000     2.770000
# 25%    3.190000e+05   2.000000    3.940000       8.000000     3.150000
# 50%    3.900000e+05   2.000000    4.930000       9.000000     3.400000
# 75%    5.125000e+05   3.000000    5.580000      10.000000     3.685000
# max    3.686000e+06   4.000000    8.080000      22.000000     4.200000
#
#               Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  EstimatedPrice
# count  219.000000   219.000000     219.000000   219.000000    2.190000e+02
# mean    29.424658   873.200913     699.977169    49.197717    4.862191e+05
# std     49.155880  1392.893683    1175.278922    18.554525    3.978582e+05
# min      0.000000     0.000000       0.000000    16.700000    2.883650e+04
# 25%      0.000000     0.000000       0.000000    36.100000    3.074488e+05
# 50%      0.000000     0.000000       0.000000    50.000000    3.919800e+05
# 75%     41.000000  2614.000000    1344.000000    59.500000    5.324750e+05
# max    131.000000  7405.000000    6422.000000    93.900000    3.973508e+06

# %%
house_data.dtypes
# Out:
# Address            object
# Neighborhood       object
# HouseType          object
# Price               int64
# Bath              float64
# CrimeIndex        float64
# MinutesToLoop       int64
# MilesToLake       float64
# Age                 int64
# LotSizeSqft         int64
# HouseSizeSqft       int64
# SchoolIndex       float64
# EstimatedPrice    float64
# dtype: object

# %%
house_data.describe(include=['object'])
# Out:
#                                    Address Neighborhood HouseType
# count                                  219          219       216
# unique                                 219            1         5
# top     2045 W Concord Pl #504, Chicago IL  Wicker Park     Condo
# freq                                     1          219       146

# %%
house_data.describe(include='all')
# Out:
#                                    Address Neighborhood HouseType  \
# count                                  219          219       216
# unique                                 219            1         5
# top     2045 W Concord Pl #504, Chicago IL  Wicker Park     Condo
# freq                                     1          219       146
# mean                                   NaN          NaN       NaN
# std                                    NaN          NaN       NaN
# min                                    NaN          NaN       NaN
# 25%                                    NaN          NaN       NaN
# 50%                                    NaN          NaN       NaN
# 75%                                    NaN          NaN       NaN
# max                                    NaN          NaN       NaN
#
#                Price       Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# count   2.190000e+02  70.000000  219.000000     219.000000   219.000000
# unique           NaN        NaN         NaN            NaN          NaN
# top              NaN        NaN         NaN            NaN          NaN
# freq             NaN        NaN         NaN            NaN          NaN
# mean    4.834311e+05   2.271429    4.663607       9.698630     3.420411
# std     4.001249e+05   0.883364    1.418146       2.898995     0.352522
# min     2.450000e+04   1.000000    1.090000       6.000000     2.770000
# 25%     3.190000e+05   2.000000    3.940000       8.000000     3.150000
# 50%     3.900000e+05   2.000000    4.930000       9.000000     3.400000
# 75%     5.125000e+05   3.000000    5.580000      10.000000     3.685000
# max     3.686000e+06   4.000000    8.080000      22.000000     4.200000
#
#                Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  EstimatedPrice
# count   219.000000   219.000000     219.000000   219.000000    2.190000e+02
# unique         NaN          NaN            NaN          NaN             NaN
# top            NaN          NaN            NaN          NaN             NaN
# freq           NaN          NaN            NaN          NaN             NaN
# mean     29.424658   873.200913     699.977169    49.197717    4.862191e+05
# std      49.155880  1392.893683    1175.278922    18.554525    3.978582e+05
# min       0.000000     0.000000       0.000000    16.700000    2.883650e+04
# 25%       0.000000     0.000000       0.000000    36.100000    3.074488e+05
# 50%       0.000000     0.000000       0.000000    50.000000    3.919800e+05
# 75%      41.000000  2614.000000    1344.000000    59.500000    5.324750e+05
# max     131.000000  7405.000000    6422.000000    93.900000    3.973508e+06

# %%
# Look for any linear correlations in the data
house_data.corr()
# Out:
#                    Price      Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# Price           1.000000  0.113943    0.118667      -0.034644    -0.072433
# Bath            0.113943  1.000000    0.163785       0.166330    -0.157517
# CrimeIndex      0.118667  0.163785    1.000000       0.194745     0.102382
# MinutesToLoop  -0.034644  0.166330    0.194745       1.000000     0.374829
# MilesToLake    -0.072433 -0.157517    0.102382       0.374829     1.000000
# Age             0.237720 -0.039220   -0.036644      -0.023820    -0.047087
# LotSizeSqft     0.443341 -0.029979   -0.008807      -0.053292     0.006240
# HouseSizeSqft   0.456272  0.698526    0.070952      -0.032437    -0.046517
# SchoolIndex    -0.072403 -0.047992   -0.100256      -0.196728    -0.205966
# EstimatedPrice  0.983784  0.105632    0.122793      -0.034185    -0.082604
#
#                      Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  \
# Price           0.237720     0.443341       0.456272    -0.072403
# Bath           -0.039220    -0.029979       0.698526    -0.047992
# CrimeIndex     -0.036644    -0.008807       0.070952    -0.100256
# MinutesToLoop  -0.023820    -0.053292      -0.032437    -0.196728
# MilesToLake    -0.047087     0.006240      -0.046517    -0.205966
# Age             1.000000     0.716774       0.645147    -0.029953
# LotSizeSqft     0.716774     1.000000       0.828598    -0.055458
# HouseSizeSqft   0.645147     0.828598       1.000000    -0.023378
# SchoolIndex    -0.029953    -0.055458      -0.023378     1.000000
# EstimatedPrice  0.255628     0.454939       0.471783    -0.073825
#
#                 EstimatedPrice
# Price                 0.983784
# Bath                  0.105632
# CrimeIndex            0.122793
# MinutesToLoop        -0.034185
# MilesToLake          -0.082604
# Age                   0.255628
# LotSizeSqft           0.454939
# HouseSizeSqft         0.471783
# SchoolIndex          -0.073825
# EstimatedPrice        1.000000

# %%
# Plot each variable against each other 
# scroll down past the subplot information
pd.scatter_matrix(house_data, figsize=(15,15))
# Out:
# /anaconda3/envs/DataScience/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a241c29e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a242c06a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24398940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243ceb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2440e4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2440e518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24473710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a244aad30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a244e88d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2451d320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24550908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24583f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a245c4b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a245d07b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2462bcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2466a320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2469ce80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a246e04e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24707f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a247474e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2477ca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a247bc0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24750860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24820940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24862400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24896f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a248c2240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a248ffcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2493c6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24972cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a249b2780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a249e4080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a19630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a4dc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a902b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a22278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24af4a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24b344e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24b69b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24baa080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24bcfda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24c11860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24c47e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24c874e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24cb7550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24cebbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d2d240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d64860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d42a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24dd1080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24e086a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e3dc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e7c7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24eaf390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ee39b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24f14ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24f57a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24f895c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24fbfb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25000160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a25036c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2503f8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2509cf60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a250dc5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2511b080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25150630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25181240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a251b77f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a251ebe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2522d400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a251c3ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25290be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a252d16a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25308cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2534a320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2536cef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a253b0470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a253e5a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a254254e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a254562b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a254897f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a254bde10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a255008d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2550bf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25567c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a255a62b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a255d9e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2561b400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2563eef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a256824e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a256b8b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a256f8080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2568cf60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a257a48d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a257e6390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2581a9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2584ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2587fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a258c2710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a258f8d30>]], dtype=object)

# %% [markdown]
# ### Questions?
#
# - Can you describe the data set - give a summary of what's happening?
# There is ten variables with the only strong linear relationship is price and estimated house price.
# - What looks to be affecting house prices from our initial inspection?
# The house size is the most influential variables to affect house prices.
# - What is the type of relationship in those variables affecting price?
# Somewhat linear.

# %%
# create a fitted model in one line i.e. y = f(X) Price = f(Bath + HouseSizeSqft)
lm = smf.ols(formula='Price ~ Bath + HouseSizeSqft', data=house_data).fit()

# print the coefficients!
lm.params
# Out:
# Intercept        508310.776747
# Bath             -28995.658012
# HouseSizeSqft       133.011874
# dtype: float64

# %% [markdown]
# The summary function provided by the statsmodel library presents lots of useful information about the resulting model.
#
# Key items to pay attention to are:
# - R-squared
# - Adj. R-Squared
# - coef (for each variable)

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.340
# Date:                Thu, 01 Mar 2018   Prob (F-statistic):              0.269
# Time:                        22:08:36   Log-Likelihood:                -1030.2
# No. Observations:                  70   AIC:                             2066.
# Df Residuals:                      67   BIC:                             2073.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      5.083e+05   2.05e+05      2.478      0.016    9.89e+04    9.18e+05
# Bath            -2.9e+04   1.16e+05     -0.250      0.803   -2.61e+05    2.03e+05
# HouseSizeSqft   133.0119     99.854      1.332      0.187     -66.297     332.321
# ==============================================================================
# Omnibus:                       85.337   Durbin-Watson:                   1.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              891.863
# Skew:                           3.754   Prob(JB):                    2.16e-194
# Kurtosis:                      18.793   Cond. No.                     7.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# What would you expect a house price to be for a house with 3 bathrooms and 350 sqft?
# Calculate it.
508310 -28995.66*3 + 133*350
# Out:
# 467873.02

# %%
275142 - 66*3 + 133*350
# Out:
# 321494

# %% [markdown]
# ## Student Excercise

# %% [markdown]
# Now try creating a regression from just the EstimatedPrice

# %%
# check the distribution of Price vs. EstimatedPrice using a scatterplot
import seaborn as sns
sns.set_style("darkgrid")

sns.lmplot(y='Price', x='EstimatedPrice', data=house_data)

# %%
# Let's try just modelling just using the estimated price
# create a fitted model in one line
lm = smf.ols(formula='Price ~ EstimatedPrice ', data=house_data).fit()

# print the coefficients
lm.params
# Out:
# Intercept         2371.037940
# EstimatedPrice       0.989389
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     6529.
# Date:                Thu, 01 Mar 2018   Prob (F-statistic):          6.25e-164
# Time:                        22:08:36   Log-Likelihood:                -2758.9
# No. Observations:                 219   AIC:                             5522.
# Df Residuals:                     217   BIC:                             5529.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       2371.0379   7685.764      0.308      0.758   -1.28e+04    1.75e+04
# EstimatedPrice     0.9894      0.012     80.801      0.000       0.965       1.014
# ==============================================================================
# Omnibus:                      198.218   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8006.566
# Skew:                           3.156   Prob(JB):                         0.00
# Kurtosis:                      31.941   Cond. No.                     9.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Question:
# Did the model build on just Estimated Price have a better R-Squared value than the prior model built using Bath and HouseSizeSqft?
#
# Yes, it was a much better model to predict price.

# %% [markdown]
# ### Predicting Price using the built model

# %% [markdown]
# Now we will find out what the model estimates the price will be for the the minimum and maximium values of EstimatedPrice

# %%
# create a DataFrame with the minimum and maximum values of EstimatedPrice
# these values will be used in the built model to predict the Price
X_new = pd.DataFrame({'EstimatedPrice': [house_data.EstimatedPrice.min(), house_data.EstimatedPrice.max()]})
X_new.head()
# Out:
#    EstimatedPrice
# 0         28836.5
# 1       3973508.0

# %%
# predict price given two data points and the built model

preds = lm.predict(X_new)
preds
# Out:
# 0    3.090156e+04
# 1    3.933717e+06
# dtype: float64

# %% [markdown]
# Now lets view a line representing the model build off just Estimated Price, over a scatter plot of the data of Price vs. EstimatedPrice.
#
# To produce the line overlay, we will simply plot a straight line between the two predicted points over the scatter plot.

# %%
# first, plot the observed data
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')

# %%
# Now, plot a line over the points that uses just the two points
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')
# this code overlays a straight line between the the coordinates created by X_new and preds
plt.plot(X_new, preds, c='red', linewidth=2)

# %% [markdown]
# ### Experiment
# Now try creating new models by selecting different variables or combinations of variables. Can you get a better fit?

# %%
# create a fitted model in one line i.e. y = f(X) Price = f(Bath + HouseSizeSqft)
lm = smf.ols(formula='Price ~ HouseSizeSqft + LotSizeSqft', data=house_data).fit()

# print the coefficients!
lm.params
# Out:
# Intercept        363581.655424
# HouseSizeSqft        96.588033
# LotSizeSqft          59.825838
# dtype: float64

# %%
df = house_data[house_data.LotSizeSqft != 0]

# %%
# create a DataFrame with the minimum and maximum values of EstimatedPrice
# these values will be used in the built model to predict the Price
y_new = pd.DataFrame({'LotSizeSqft': [df.LotSizeSqft.min(), df.LotSizeSqft.max()]})
y_new.head()
# Out:
#    LotSizeSqft
# 0          436
# 1         7405

# %%
# first, plot the observed data

df.plot(kind='scatter', x='LotSizeSqft', y='Price')

# %%
# Now, plot a line over the points that uses just the two points
df.plot(kind='scatter', x='LotSizeSqft', y='Price')
# this code overlays a straight line between the the coordinates created by X_new and preds
plt.plot(y_new, preds, c='red', linewidth=2)

# %% [markdown]
# ## Themepark

# %% [markdown]
# The file **themepark.csv** has some data from a theme park. Children were asked to rate their experience on a scale
# from 0-5. This data was compared against the number of hours they spent in the park.

# %%
# !ls

# %%
# Create a pandas DataFrame from this data by reading it in using pandas. 
# Read in data
df = pd.read_csv("themepark.csv")
# It is located in the same directory as this notebook, so you will not need to provide a filepath.

# %%
# Have a look at the data (e.g. display the head or tail, use describe, etc.)
df.head()
# Out:
#    Hours  Enjoyment
# 0      1          1
# 1      2          3
# 2      3          4
# 3      4          5
# 4      5          5

# %%
# create a fitted model in one line i.e. y = f(X) Price = f(Bath + HouseSizeSqft)
lm = smf.ols(formula='Enjoyment ~ Hours', data=df).fit()

# print the coefficients!
lm.params
# Out:
# Intercept    0.663087
# Hours        0.906711
# dtype: float64

# %%
a_new = pd.DataFrame({'Hours': [df.Hours.min(), df.Hours.max()]})
a_new.head()
# Out:
#    Hours
# 0      1
# 1      5

# %%
# predict price given two data points and the built model

preds = lm.predict(a_new)
preds
# Out:
# 0    1.569799
# 1    5.196644
# dtype: float64

# %%
# Draw a scatterplot of this data.
df.plot(kind='scatter', x='Hours', y='Enjoyment')
plt.plot(a_new, preds,  c='red', linewidth=2)

# %%
# Try doing a linear regression on this data
df.corr()
# Out:
#               Hours  Enjoyment
# Hours      1.000000   0.820402
# Enjoyment  0.820402   1.000000

# %%
house_data.describe()
# Out:
#        Enjoyment
# count  27.000000
# mean    3.148148
# std     1.610153
# min     0.000000
# 25%     2.000000
# 50%     3.000000
# 75%     4.500000
# max     5.000000

# %%
# create a fitted model in one line i.e. y = f(X) Price = f(Bath + HouseSizeSqft)
lm = smf.ols(formula='Enjoyment ~ Hours', data=df).fit()

# print the coefficients!
lm.params
# Out:
# Intercept    0.663087
# Hours        0.906711
# dtype: float64

# %%
y_new = pd.DataFrame({'Enjoyment': [df.Enjoyment.min(), df.Enjoyment.max()]})
y_new.head()
# Out:
#    Enjoyment
# 0          0
# 1          5

# %%
# Plot this regression over the top of the data. Could the regression be better?

# %%
# Now, plot a line over the points that uses just the two points
df.plot(kind='scatter', x='Hours', y='Enjoyment')
# this code overlays a straight line between the the coordinates created by X_new and preds
plt.plot(y_new, preds, c='red', linewidth=2)
