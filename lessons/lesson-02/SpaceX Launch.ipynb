# %%
import pandas as pd
import numpy as np
import os
import datetime
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# download spaceX lauch data file
df = pd.read_csv(os.path.join('~/GA/W1/spacex_launches.csv'))

# %%
df.dtypes
# Out:
# Flight Number        object
# Date                 object
# Time (UTC)           object
# Booster Version      object
# Launch Site          object
# Payload              object
# Payload Mass (kg)    object
# Orbit                object
# Customer             object
# Mission Outcome      object
# Landing Outcome      object
# dtype: object

# %%
df
# Out:
#    Flight Number                Date Time (UTC)  \
# 0              1        June 4, 2010      18:45
# 1              2    December 8, 2010      15:43
# 2              3        May 22, 2012       7:44
# 3              4     October 8, 2012       0:35
# 4              5       March 1, 2013      15:10
# 5              6  September 29, 2013      16:00
# 6              7    December 3, 2013      22:41
# 7              8     January 6, 2014      22:06
# 8              9      April 18, 2014      19:25
# 9             10       July 14, 2014      15:15
# 10            11      August 5, 2014       8:00
# 11            12   September 7, 2014       5:00
# 12            13  September 21, 2014       5:52
# 13            14    January 10, 2015       9:47
# 14            15   February 11, 2015      23:03
# 15            16       March 2, 2015       3:50
# 16            17      April 14, 2015      20:10
# 17            18      April 27, 2015      23:03
# ...

# %% [markdown]
# ## What is the data for?

# %% [markdown]
# The data relates to 11 variables associated with space missions conducted by SpaceX.

# %% [markdown]
# ## What are the data types?

# %% [markdown]
# The datatypes are all objects which are numerical, date, time and string. They include flight number, date of flight, rocket type, launch site, payload, weight of payload, type of orbit, customer, outcome of mission and landing outcome. A number of the data types could be considered boolean. e.g. mission outcome either failure or success.

# %%
print(df.dtypes)
# Out:
# Flight Number        object
# Date                 object
# Time (UTC)           object
# Booster Version      object
# Launch Site          object
# Payload              object
# Payload Mass (kg)    object
# Orbit                object
# Customer             object
# Mission Outcome      object
# Landing Outcome      object
# dtype: object

# %% [markdown]
# ## What alternative uses could you think of for the dataset?

# %% [markdown]
# Sales and marketing

# %% [markdown]
# ## Plot a trend or find a relationship

# %%
for i in df.columns:
    print(i)
# Out:
# Flight Number
# Date
# Time (UTC)
# Booster Version
# Launch Site
# Payload
# Payload Mass (kg)
# Orbit
# Customer
# Mission Outcome
# Landing Outcome

# %%
# there is 49 rows of data and 11 columns
print(df.shape)
# Out:
# (49, 11)

# %%
df.describe()
# Out:
#        Flight Number             Date Time (UTC) Booster Version  Launch Site  \
# count             49               49         49              49           49
# unique            49               49         48              31            5
# top               43  August 24, 2017      23:03         F9 v1.1  CCAFS LC-40
# freq               1                1          2              15           26
#
#              Payload Payload Mass (kg) Orbit    Customer Mission Outcome  \
# count             49                47    49          49              49
# unique            49                42     6          25               3
# top     SpaceX CRS-3            9,600    LEO  NASA (CRS)         Success
# freq               1                 4    26          13              47
#
#        Landing Outcome
# count               49
# unique              14
# top         No attempt
# freq                12

# %%
print(df['Date'].head(1))
print(df['Date'].tail(1))
# Out:
# 0    June 4, 2010
# Name: Date, dtype: object
# 48    February 6, 2018
# Name: Date, dtype: object

# %%
# calculate days between first and last mission
import datetime
# date(YEAR, MONTH, DAY)
f_date = datetime.date(2010, 6, 4)
t_date = datetime.date(2017, 12, 23)
delta = t_date - f_date
print(delta)
# Out:
# 2759 days, 0:00:00

# %%
# average days between missions
mean = 2759 / 45
print(mean)
# Out:
# 61.31111111111111

# %%
df['Date'] = pd.to_datetime(df['Date'], format="%B %d, %Y").dt.year

# %%
df['Date'].head()
# Out:
# 0    2010
# 1    2010
# 2    2012
# 3    2012
# 4    2013
# Name: Date, dtype: int64

# %%
df['event'] = 1

# %%
df = df.drop(df[df.Date > 2017].index)
df
# Out:
#    Flight Number  Date Time (UTC)   Booster Version   Launch Site  \
# 0              1  2010      18:45           F9 v1.0   CCAFS LC-40
# 1              2  2010      15:43           F9 v1.0   CCAFS LC-40
# 2              3  2012       7:44           F9 v1.0   CCAFS LC-40
# 3              4  2012       0:35           F9 v1.0   CCAFS LC-40
# 4              5  2013      15:10           F9 v1.0   CCAFS LC-40
# 5              6  2013      16:00           F9 v1.1   VAFB SLC-4E
# 6              7  2013      22:41           F9 v1.1   CCAFS LC-40
# 7              8  2014      22:06           F9 v1.1   CCAFS LC-40
# 8              9  2014      19:25           F9 v1.1   CCAFS LC-40
# 9             10  2014      15:15           F9 v1.1   CCAFS LC-40
# 10            11  2014       8:00           F9 v1.1   CCAFS LC-40
# 11            12  2014       5:00           F9 v1.1   CCAFS LC-40
# 12            13  2014       5:52           F9 v1.1   CCAFS LC-40
# ...

# %%
df[['Orbit', 'event']].groupby('Orbit').sum()
# Out:
#               event
# Orbit
# GTO              18
# LEO              25
# Polar orbit       1
# SSO               1
# Sun-Earth L1      1

# %%
25/45
# Out:
# 0.5555555555555556

# %%
df = df.drop(df[df.Date > 2017].index)
byYear = df.groupby('Date')['event']
launches = byYear.sum()
launches
# Out:
# Date
# 2010     2
# 2012     2
# 2013     3
# 2014     6
# 2015     7
# 2016     8
# 2017    18
# Name: event, dtype: int64

# %%
plt.plot(launches)
plt.ylabel('Number of Missions')
plt.xlabel('Year')
plt.title('Space X missions 2010 - 2017')
plt.show()

# %%
launches.max()
# Out:
# 18

# %%
launches.mean()
# Out:
# 6.5714285714285712

# %%
launches.min()
# Out:
# 2

# %%
#Need to convert payload mass to integer
byYear = df.groupby('Date')['Payload Mass (kg)']

# %%
missions_2017

# %%
#df.sort_values(by=['Date','Payload Mass (kg)']).head()

# %%
18/8
# Out:
# 2.25

# %%
365/18
# Out:
# 20.27777777777778
